# %% [markdown]
# Preview of the data:

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels as sm
from io import StringIO
from math import pi
import plotly.plotly as py
import plotly.graph_objs as go

# %%
df = pd.read_csv('data/data.csv')

# %%
df=DataFrame(df, columns = ['Crossing','Finishing', 'HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve','FKAccuracy','LongPassing',
  'BallControl','Acceleration','SprintSpeed', 'Agility','Reactions','Balance','ShotPower','Jumping','Stamina','Strength','LongShots','Aggression','Interceptions','Positioning',
'Vision','Penalties','Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes','Name'])

# %%
playerskills = df[['Name','Dribbling','Vision','BallControl','ShotPower','Acceleration']]

# %%
playerskills = playerskills.loc[[0,25]].set_index('Name')

# %%
playerskills
# Out:
#            Dribbling  Vision  BallControl  ShotPower  Acceleration
# Name
# L. Messi        97.0    94.0         96.0       85.0          91.0
# K. Mbappé       90.0    82.0         91.0       79.0          96.0

# %%
Attributes =list(playerskills)
AttNo = len(Attributes)

# %%
#Mbappe
values2 = playerskills.iloc[1].tolist()
values2 += values2 [:1]

#Messi
values = playerskills.iloc[0].tolist()
values += values [:1]


angles = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
angles += angles [:1]

angles2 = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
angles2 += angles2 [:1]


ax = plt.subplot(111, polar=True)

plt.xticks(angles2[:-1],Attributes)

ax.plot(angles, values)
ax.fill(angles, values, 'teal', alpha=0.1)

ax.plot(angles2,values2)
ax.fill(angles2, values2, 'red', alpha=0.1)


plt.figtext(0.2,0.9,'Messi',color='Blue')
plt.figtext(0.2,0.85,'v')
plt.figtext(0.2,0.8,'Mbappé',color='Orange')
plt.show()

# %%
df
# Out:
#        Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0          84.0       95.0             70.0          90.0     86.0       97.0
# 1          84.0       94.0             89.0          81.0     87.0       88.0
# 2          79.0       87.0             62.0          84.0     84.0       96.0
# 3          17.0       13.0             21.0          50.0     13.0       18.0
# 4          93.0       82.0             55.0          92.0     82.0       86.0
# 5          81.0       84.0             61.0          89.0     80.0       95.0
# 6          86.0       72.0             55.0          93.0     76.0       90.0
# 7          77.0       93.0             77.0          82.0     88.0       87.0
# 8          66.0       60.0             91.0          78.0     66.0       63.0
# 9          13.0       11.0             15.0          29.0     13.0       12.0
# 10         62.0       91.0             85.0          83.0     89.0       85.0
# ...

# %%
skills=df.drop(['Name','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes'],axis=1)

# %%
corr = skills.corr()

plt.figure(figsize = (35,25))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,annot=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
